# %%
import pandas as pd
import numpy as np

df= pd.read_csv(r'.\Data\combined_assam 2018-12-01 to 2025-02-01.csv')
solar_df= df[['datetime','solarenergy']].copy()
solar_df['datetime'] = pd.to_datetime(solar_df['datetime'])
solar_df.set_index('datetime', inplace=True)

# %%
from matplotlib import pyplot 
solar_df['solarenergy'].plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=solar_df.index, y=solar_df['solarenergy'], mode='lines', name='Solar Energy'))
fig.update_layout(title='Solar Energy Over Time',
                  xaxis_title='Date',
                  yaxis_title='Solar Energy (kWh)',
                  template='plotly_dark')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File e:\SolarAndWind\venv\Lib\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File e:\SolarAndWind\venv\Lib\site-packages\plotly\basedatatypes.py:846, in BaseFigure._ipython_display_(self)
#     843 import plotly.io as pio
#     845 if pio.renderers.render_on_display and pio.renderers.default:
# --> 846     pio.show(self)
#     847 else:
#     848     print(repr(self))
#
# File e:\SolarAndWind\venv\Lib\site-packages\plotly\io\_renderers.py:425, in show(fig, renderer, validate, **kwargs)
#     420     raise ValueError(
#     421         "Mime type rendering requires ipython but it is not installed"
#     422     )
# ...

# %% [markdown]
# <h2 style="color: purple; font-weight: bold; font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; padding: 8px 12px; border-left: 4px solid purple; border-radius: 4px; box-shadow: 1px 1px 4px rgba(0,0,0,0.1);">🚀 Training LSTM</h2>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM ,Input

n_steps=15
n_features=1
model = Sequential()
model.add( Input(shape=(n_steps, n_features)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(150,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from tensorflow.keras.models import Sequential
#       2 from tensorflow.keras.layers import Dense, LSTM ,Input
#       4 n_steps=15
#
# File e:\SolarAndWind\tf-env\lib\site-packages\tensorflow\__init__.py:37
#      34 import sys as _sys
#      35 import typing as _typing
# ---> 37 from tensorflow.python.tools import module_util as _module_util
#      38 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      40 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File e:\SolarAndWind\tf-env\lib\site-packages\tensorflow\python\__init__.py:42
#      37 from tensorflow.python.eager import context
#      39 # pylint: enable=wildcard-import
#      40
#      41 # Bring in subpackages.
# ---> 42 from tensorflow.python import data
# ...

# %%
model.fit(TrainX, TrainY, validation_data=(TestX,TestY), epochs=95,batch_size=5, verbose=1 )
