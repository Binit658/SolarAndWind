# %%
import pandas as pd
import numpy as np

energy_df= pd.read_csv(r'.\Data\india_monthly_full_release_long_format.csv')
energy_df=energy_df[['State',  'Date',
       'Category', 'Variable', 'Unit', 'Value',]]

# %%
weather_df= pd.read_csv(r'.\Data\assam 2018-12-01 to 2021-02-01.csv')
weather_df=weather_df[['datetime', 'tempmax', 'tempmin', 'temp', 'dew', 'humidity', 'precip', 'precipprob',
       'precipcover',  'snow', 'snowdepth', 'windgust',
       'windspeed', 'winddir', 'sealevelpressure', 'cloudcover', 'visibility',
       'solarradiation', 'solarenergy', 'uvindex', 'severerisk', 'moonphase']]
weather_df['datetime'] = pd.to_datetime(weather_df['datetime'])
weather_df.set_index('datetime', inplace=True)
monthly_weather = weather_df.resample('ME').mean()
# print(weather_df.dtypes)
monthly_weather
# Out:
#               tempmax    tempmin       temp        dew   humidity    precip  \
# datetime
# 2018-12-31  77.474194  57.167742  66.477419  60.248387  82.051613  0.030839
# 2019-01-31  78.129032  53.393548  64.612903  56.200000  76.532258  0.000258
# 2019-02-28  80.339286  58.371429  68.614286  58.882143  73.600000  0.018893
# 2019-03-31  86.687097  62.964516  74.741935  60.903226  65.329032  0.069613
# 2019-04-30  86.706667  70.660000  78.530000  70.680000  78.513333  0.212867
# 2019-05-31  87.038710  74.067742  80.351613  75.700000  86.535484  0.420968
# 2019-06-30  92.603333  79.583333  85.866667  80.500000  84.900000  0.243467
# 2019-07-31  90.177419  79.929032  85.045161  80.829032  87.822581  0.429000
# 2019-08-31  94.522581  80.938710  86.970968  80.890323  83.087097  0.105484
# 2019-09-30  89.086667  78.003333  83.016667  78.933333  88.143333  0.396667
# 2019-10-31  87.087097  73.516129  80.022581  74.838710  85.132258  0.196806
# ...

# %%
energy_df=energy_df[(energy_df['Variable']=='Solar') & ( energy_df['Category']=='Electricity generation') & (energy_df['Unit']=='GWh')]
energy_df[(energy_df['State']=='Assam')].head()
# Out:
# State       74
# Date        74
# Category    74
# Variable    74
# Unit        74
# Value       74
# dtype: int64
